# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

SAVE_FIG    = True
TARGET_TN   = 25

EXCEL_ROOT  = Path.cwd().parent

METRIC_8 = "accuracy8_mean"
METRIC_3 = "accuracy3_mean"
